# %%
import cv2 as cv
import numpy as np

# %%
image = cv.imread("Screenshot 2024-11-20 184405.png", cv.IMREAD_GRAYSCALE)
# img_bw = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

# %%
# cv.imshow("original image",image)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image)

# %%
plt.imshow(img_bw)

# %%
clahe = cv.createCLAHE(clipLimit = 5, tileGridSize=(15, 15))
final_img = clahe.apply(image)

# %%
plt.imshow(final_img)

# %%
clahe = cv.createCLAHE(clipLimit = 25, tileGridSize=(15, 15))
final_img = clahe.apply(image)

# %%
plt.imshow(final_img)

# %%
final_img.shape, image.shape
# Out:
# ((247, 361), (247, 361))

# %%
img = cv.imread("Screenshot 2024-11-20 184405.png")
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
fin_img = img[:,:, 1]

# %%
plt.imshow(fin_img)

# %%
fin = clahe.apply(fin_img)

# %%
plt.imshow(fin)
